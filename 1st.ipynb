# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhkumar27/saurabh/blob/master/1st.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a = 4

# %%
a
# Out:
# 4

# %%
import pandas as pd

# %%
df = dict({'name' : ['saurabh','kumar','sonu','raj','ash','cash'], 'class':[1,2,3,5,4,6], 'marks':[44,23,41,67,88,98], 'roll':[43,23,89,76,65,31]})

# %%
abc = pd.DataFrame(df)

# %%
abc
# Out:
#    class  marks     name  roll
# 0      1     44  saurabh    43
# 1      2     23    kumar    23
# 2      3     41     sonu    89
# 3      5     67      raj    76
# 4      4     88      ash    65
# 5      6     98     cash    31

# %%
type(abc)
# Out:
# pandas.core.frame.DataFrame

# %%
abc.describe()
# Out:
#           class      marks       roll
# count  6.000000   6.000000   6.000000
# mean   3.500000  60.166667  54.500000
# std    1.870829  29.198744  26.227848
# min    1.000000  23.000000  23.000000
# 25%    2.250000  41.750000  34.000000
# 50%    3.500000  55.500000  54.000000
# 75%    4.750000  82.750000  73.250000
# max    6.000000  98.000000  89.000000

# %%
df1 = abc.describe(include = ['object','int'], percentiles = ab)

# %%
import numpy as np

# %%
ab = list(np.arange(0.01,1.01,.01))

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1
# Out:
#            class      marks name       roll
# count   6.000000   6.000000    6   6.000000
# unique       NaN        NaN    6        NaN
# top          NaN        NaN  raj        NaN
# freq         NaN        NaN    1        NaN
# mean    3.500000  60.166667  NaN  54.500000
# std     1.870829  29.198744  NaN  26.227848
# min     1.000000  23.000000  NaN  23.000000
# 1%      1.050000  23.900000  NaN  23.400000
# 2%      1.100000  24.800000  NaN  23.800000
# 3%      1.150000  25.700000  NaN  24.200000
# 4%      1.200000  26.600000  NaN  24.600000
# 5%      1.250000  27.500000  NaN  25.000000
# 6.0%    1.300000  28.400000  NaN  25.400000
# 7.0%    1.350000  29.300000  NaN  25.800000
# 8%      1.400000  30.200000  NaN  26.200000
# 9%      1.450000  31.100000  NaN  26.600000
# 10%     1.500000  32.000000  NaN  27.000000
# 11%     1.550000  32.900000  NaN  27.400000
# 12%     1.600000  33.800000  NaN  27.800000
# 13%     1.650000  34.700000  NaN  28.200000
# ...
